# %%
from ultralytics import YOLO

# Load the trained model
model = YOLO("best_1.pt")

# Print class names and number of classes
print("Class Names:", model.names)
print("Number of Classes:", model.model.nc)
# Out:
# Class Names: {0: 'car'}
# Number of Classes: 1

# %%
import os
from ultralytics import YOLO
from pathlib import Path
import cv2

# Load your trained model
model = YOLO("final_best-tara.pt")

# Folder containing images
image_folder = "../../Data/Indoor/1pm/1A/"

# Supported image formats
image_extensions = ['.jpg', '.jpeg', '.png', '.bmp']

# Loop through all image files
for image_file in os.listdir(image_folder):
    if any(image_file.endswith(ext) for ext in image_extensions):
        image_path = os.path.join(image_folder, image_file)

        # Run inference with lowered confidence threshold
        results = model(image_path, conf=0.15)

        print(f"\n🔍 Results for {image_file}:")
        for result in results:
            boxes = result.boxes
            for box in boxes:
                cls_id = int(box.cls[0])
                confidence = float(box.conf[0])
                class_name = model.names[cls_id]
                print(f"Detected: {class_name} ({confidence:.2f})")

        # Optional: visualize results
        results[0].show()  # Opens an OpenCV window
# Out:
# image 1/1 /Users/tara/COS40007/COS4007-Theme2/smart-parking-system/server/venv/../../Data/Indoor/1pm/1A/1A-6.jpeg: 480x640 6 cars, 113.2ms
# Speed: 6.2ms preprocess, 113.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 🔍 Results for 1A-6.jpeg:
# Detected: car (0.89)
# Detected: car (0.87)
# Detected: car (0.86)
# Detected: car (0.85)
# Detected: car (0.77)
# Detected: car (0.44)
#
# image 1/1 /Users/tara/COS40007/COS4007-Theme2/smart-parking-system/server/venv/../../Data/Indoor/1pm/1A/1A-1.jpeg: 480x640 9 cars, 126.5ms
# Speed: 4.1ms preprocess, 126.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 🔍 Results for 1A-1.jpeg:
# Detected: car (0.87)
# Detected: car (0.87)
# Detected: car (0.86)
# Detected: car (0.86)
# Detected: car (0.86)
# Detected: car (0.85)
# Detected: car (0.83)
# Detected: car (0.62)
# Detected: car (0.60)
#
# ...
